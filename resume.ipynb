# %%
# Text Variables
Name = 'Nikita Patil'
Title = 'Data Science & Analytics'
Contact = 'Dallas, TX\n4693804573\p.nikita270896@gmail.com\nwww.linkedin.com/in/nikita-nitin-patil\nhttps://nikitanitinpatil.github.io/'
ProjectsHeader = 'PROJECTS/PUBLICATIONS'
ProjectOneTitle = 'Recommendation systems'
ProjectOneDesc = '- Built a popularity based recommendation system\n- Cleaned/visualized data using pandas and numpy/matplotlib libraries in Python'
ProjectTwoTitle = 'Titanic Survival'
ProjectTwoDesc = '- Used titanic dataset for predicting the survival rates of passengers on board.\n- Used PDE and visualization to determine correlations for future study'
ProjectThreeTitle = 'Pandas Cleaning and Visualization'
ProjectThreeDesc = '- Cleaned data for analysis using pandas library in Python\n- Used pandas and matplotlib to explore which cars hold the most value over time'
ProjectFourTitle = 'Trucking'
ProjectFourDesc = '- Established connection between cloud era platform and tableau\n to perform visualization for the given dataset,to study its results\n and to identify dangerous commercial truck drivers nationwide.'
Portfolio = 'https://nikitanitinpatil.github.io/'
WorkHeader = 'RECENT WORK EXPERIENCE'
WorkOneTitle = 'Callier Center for Communication Disabilities and Child Development '
WorkOneTime = '2018-2020'
WorkOneDesc = '\n- Developed and designed reports and dashboards\n using variety of data mining and presentation tools\n- Build, update, and maintain Tableau and Power BI dashboards\n- Build, maintain and support data-driven applications and related infrastructure'
CodeTitle = 'Portfolio'
CodeTitle2 = 'LICIENCES AND CERTIFICATIONS'
CodeTitle2Desc = '- Applied Machine Learning Foundations\n- DevOps for Data Scientists\n- Tableau Essential Training '

EduHeader = 'EDUCATION'
EduOneTitle = 'The University of Texas at Dallas, Master of Science'
EduOneTime = '2018-2020'
EduOneDesc = '- Major: Information Technology and Management'
EduTwoTitle = 'Savitribai Phule Pune University, Bachelor of Engineering'
EduTwoTime = '2014-2018'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Panas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'PORTFOLIO'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#58C1B2', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#6565BF', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#6565BF', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8)
plt.annotate(ProjectsHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.79), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.748), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.71), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.672), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.638), weight='regular', fontsize=9)
plt.annotate(ProjectFourTitle, (0.02,.599), weight='bold', fontsize=10)
plt.annotate(ProjectFourDesc, (.04,.55), weight='regular', fontsize=9)
plt.annotate(WorkHeader, (.02,.50), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.472), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.02,.457), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.390), weight='regular', fontsize=9)
plt.annotate(CodeTitle, (.02,.260), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(Portfolio, (.02,.235), weight='bold', fontsize=10)
plt.annotate(CodeTitle2, (.02,.350), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(CodeTitle2Desc, (.02,.295), weight='regular', fontsize=9)

plt.annotate(EduHeader, (.02,.185), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.155), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.14), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.125), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.08), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.065), weight='regular', fontsize=9, alpha=.6)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10)
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10)
plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10)
plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=10)

plt.savefig('resumeexample.png', dpi=300, bbox_inches='tight')

# %%
#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('ekresumecode.png')
imagebox = OffsetImage(arr_code, zoom=0.5)
ab = AnnotationBbox(imagebox, (0.84, 0.12))
ax.add_artist(ab)

plt.savefig('resumeexample.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-b655a275a45b> in <module>
#       2 from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
#       3 import matplotlib.image as mpimg
# ----> 4 arr_code = mpimg.imread('ekresumecode.png')
#       5 imagebox = OffsetImage(arr_code, zoom=0.5)
#       6 ab = AnnotationBbox(imagebox, (0.84, 0.12))
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1431             return handler(fd)
#    1432         else:
# -> 1433             with open(fname, 'rb') as fd:
#    1434                 return handler(fd)
#    1435     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ekresumecode.png'
